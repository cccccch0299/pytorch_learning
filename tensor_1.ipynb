# %% [markdown]
# 创建基础tensor

# %%
import torch
a = torch.tensor([2,3,4])
print(a)
# Out:
# tensor([2, 3, 4])

# %% [markdown]
# 全0/全1

# %%
b = torch.zeros(3,1)
c = torch.ones(1,3)
print(b)
print(c)
# Out:
# tensor([[0.],
#         [0.],
#         [0.]])
# tensor([[1., 1., 1.]])
